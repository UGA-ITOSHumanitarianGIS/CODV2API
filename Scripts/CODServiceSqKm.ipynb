# %%
###UGA- Carl Vinson Institute of Government - ITOS
###Description: Notebook to collect all published humanitarian map feature services and associate 
###   the appropriate equal area projection to use to project from the WGS84 Mercator 
###   projection so that square miles may be obtained for the administrative units 
###Date: February 20, 2023

###import libraries
import json
import requests
import re
import os
#now query the edgematch endpoint to get the list of service
url = 'https://gistmaps.itos.uga.edu/arcgis/rest/services/COD_External?f=json'
ret = requests.get(url)
if ret.status_code > 206:
    raise Exception(' application did not handle import success message properly.')
obj = json.loads(json.dumps(ret.json()))
loc = os.getcwd()

idx = loc.rfind('\\')
o = loc[idx+1:len(loc)]
lgdb = o + '.gdb'
wsp = loc + '\\' + lgdb
arcpy.env.workspace = wsp
aprx = arcpy.mp.ArcGISProject("current")
map = aprx.listMaps()[0]
continentsISO = [('AFG', 'Asia'), ('ALA', 'Europe Albers Equal Area Conic'), ('ALB', 'Europe Albers Equal Area Conic'),  ('DZA', 'Africa Albers Equal Area Conic'),  ('ASM', 'Oceania'),  ('AND', 'Europe Albers Equal Area Conic'),  ('AGO', 'Africa Albers Equal Area Conic'),  ('AIA', 'North America Albers Equal Area Conic'),  ('ATA', 'Antarctica'),  ('ATG', 'North America Albers Equal Area Conic'),  ('ARG', 'South America Albers Equal Area Conic'),  ('ARM', 'Asia South Albers Equal Area Conic'),  ('ABW', 'North America Albers Equal Area Conic'),  ('AUS', 'Oceania'),  ('AUT', 'Europe Albers Equal Area Conic'),  ('AZE', 'Asia South Albers Equal Area Conic'),  ('BHS', 'North America Albers Equal Area Conic'),  ('BHR', 'Asia South Albers Equal Area Conic'),  ('BGD', 'Asia South Albers Equal Area Conic'),  ('BRB', 'North America Albers Equal Area Conic'),  ('BLR', 'Europe Albers Equal Area Conic'),  ('BEL', 'Europe Albers Equal Area Conic'),  ('BLZ', 'North America Albers Equal Area Conic'),  ('BEN', 'Africa Albers Equal Area Conic'),  ('BMU', 'North America Albers Equal Area Conic'),  ('BTN', 'Asia South Albers Equal Area Conic'),  ('BOL', 'South America Albers Equal Area Conic'),  ('BES', 'North America Albers Equal Area Conic'),  ('BIH', 'Europe Albers Equal Area Conic'),  ('BWA', 'Africa Albers Equal Area Conic'),  ('BVT', 'South America Albers Equal Area Conic'),  ('BRA', 'South America Albers Equal Area Conic'),  ('IOT', 'Africa Albers Equal Area Conic'),  ('VGB', 'North America Albers Equal Area Conic'),  ('BRN', 'Asia South Albers Equal Area Conic'),  ('BGR', 'Europe Albers Equal Area Conic'),  ('BFA', 'Africa Albers Equal Area Conic'),  ('BDI', 'Africa Albers Equal Area Conic'),  ('CPV', 'Africa Albers Equal Area Conic'),  ('KHM', 'Asia South Albers Equal Area Conic'),  ('CMR', 'Africa Albers Equal Area Conic'),  ('CAN', 'North America Albers Equal Area Conic'),  ('CYM', 'North America Albers Equal Area Conic'),  ('CAF', 'Africa Albers Equal Area Conic'),  ('TCD', 'Africa Albers Equal Area Conic'),  ('CHL', 'South America Albers Equal Area Conic'),  ('CHN', 'Asia South Albers Equal Area Conic'),  ('HKG', 'Asia South Albers Equal Area Conic'),  ('MAC', 'Asia South Albers Equal Area Conic'),  ('CXR', 'Oceania'),  ('CCK', 'Oceania'),  ('COL', 'South America Albers Equal Area Conic'),  ('COM', 'Africa Albers Equal Area Conic'),  ('COG', 'Africa Albers Equal Area Conic'),  ('COK', 'Oceania'),  ('CRI', 'North America Albers Equal Area Conic'),  ('CIV', 'Africa Albers Equal Area Conic'),  ('HRV', 'Europe Albers Equal Area Conic'),  ('CUB', 'North America Albers Equal Area Conic'),  ('CUW', 'North America Albers Equal Area Conic'),  ('CYP', 'Asia South Albers Equal Area Conic'),  ('CZE', 'Europe Albers Equal Area Conic'),  ('PRK', 'Asia South Albers Equal Area Conic'),  ('COD', 'Africa Albers Equal Area Conic'),  ('DNK', 'Europe Albers Equal Area Conic'),  ('DJI', 'Africa Albers Equal Area Conic'),  ('DMA', 'North America Albers Equal Area Conic'),  ('DOM', 'North America Albers Equal Area Conic'),  ('ECU', 'South America Albers Equal Area Conic'),  ('EGY', 'Africa Albers Equal Area Conic'),  ('SLV', 'North America Albers Equal Area Conic'),  ('GNQ', 'Africa Albers Equal Area Conic'),  ('ERI', 'Africa Albers Equal Area Conic'),  ('EST', 'Europe Albers Equal Area Conic'),  ('SWZ', 'Africa Albers Equal Area Conic'),  ('ETH', 'Africa Albers Equal Area Conic'),  ('FLK', 'South America Albers Equal Area Conic'),  ('FRO', 'Europe Albers Equal Area Conic'),  ('FJI', 'Oceania'),  ('FIN', 'Europe Albers Equal Area Conic'),  ('FRA', 'Europe Albers Equal Area Conic'),  ('GUF', 'South America Albers Equal Area Conic'),  ('PYF', 'Oceania'),  ('ATF', 'Africa Albers Equal Area Conic'),  ('GAB', 'Africa Albers Equal Area Conic'),  ('GMB', 'Africa Albers Equal Area Conic'),  ('GEO', 'Asia South Albers Equal Area Conic'),  ('DEU', 'Europe Albers Equal Area Conic'),  ('GHA', 'Africa Albers Equal Area Conic'),  ('GIB', 'Europe Albers Equal Area Conic'),  ('GRC', 'Europe Albers Equal Area Conic'),  ('GRL', 'North America Albers Equal Area Conic'),  ('GRD', 'North America Albers Equal Area Conic'),  ('GLP', 'North America Albers Equal Area Conic'),  ('GUM', 'Oceania'),  ('GTM', 'North America Albers Equal Area Conic'),  ('GGY', 'Europe Albers Equal Area Conic'),  ('GIN', 'Africa Albers Equal Area Conic'),  ('GNB', 'Africa Albers Equal Area Conic'),  ('GUY', 'South America Albers Equal Area Conic'),  ('HTI', 'North America Albers Equal Area Conic'),  ('HMD', 'Oceania'),  ('VAT', 'Europe Albers Equal Area Conic'),  ('HND', 'North America Albers Equal Area Conic'),  ('HUN', 'Europe Albers Equal Area Conic'),  ('ISL', 'Europe Albers Equal Area Conic'),  ('IND', 'Asia South Albers Equal Area Conic'),  ('IDN', 'Asia South Albers Equal Area Conic'),  ('IRN', 'Asia South Albers Equal Area Conic'),  ('IRQ', 'Asia South Albers Equal Area Conic'),  ('IRL', 'Europe Albers Equal Area Conic'),  ('IMN', 'Europe Albers Equal Area Conic'),  ('ISR', 'Asia South Albers Equal Area Conic'),  ('ITA', 'Europe Albers Equal Area Conic'),  ('JAM', 'North America Albers Equal Area Conic'),  ('JPN', 'Asia South Albers Equal Area Conic'),  ('JEY', 'Europe Albers Equal Area Conic'),  ('JOR', 'Asia South Albers Equal Area Conic'),  ('KAZ', 'Asia South Albers Equal Area Conic'),  ('KEN', 'Africa Albers Equal Area Conic'),  ('KIR', 'Oceania'),  ('KWT', 'Asia South Albers Equal Area Conic'),  ('KGZ', 'Asia South Albers Equal Area Conic'),  ('LAO', 'Asia South Albers Equal Area Conic'),  ('LVA', 'Europe Albers Equal Area Conic'),  ('LBN', 'Asia South Albers Equal Area Conic'),  ('LSO', 'Africa Albers Equal Area Conic'),  ('LBR', 'Africa Albers Equal Area Conic'),  ('LBY', 'Africa Albers Equal Area Conic'),  ('LIE', 'Europe Albers Equal Area Conic'),  ('LTU', 'Europe Albers Equal Area Conic'),  ('LUX', 'Europe Albers Equal Area Conic'),  ('MDG', 'Africa Albers Equal Area Conic'),  ('MWI', 'Africa Albers Equal Area Conic'),  ('MYS', 'Asia South Albers Equal Area Conic'),  ('MDV', 'Asia South Albers Equal Area Conic'),  ('MLI', 'Africa Albers Equal Area Conic'),  ('MLT', 'Europe Albers Equal Area Conic'),  ('MHL', 'Oceania'),  ('MTQ', 'North America Albers Equal Area Conic'),  ('MRT', 'Africa Albers Equal Area Conic'),  ('MUS', 'Africa Albers Equal Area Conic'),  ('MYT', 'Africa Albers Equal Area Conic'),  ('MEX', 'North America Albers Equal Area Conic'),  ('FSM', 'Oceania'),  ('MCO', 'Europe Albers Equal Area Conic'),  ('MNG', 'Asia South Albers Equal Area Conic'),  ('MNE', 'Europe Albers Equal Area Conic'),  ('MSR', 'North America Albers Equal Area Conic'),  ('MAR', 'Africa Albers Equal Area Conic'),  ('MOZ', 'Africa Albers Equal Area Conic'),  ('MMR', 'Asia South Albers Equal Area Conic'),  ('NAM', 'Africa Albers Equal Area Conic'),  ('NRU', 'Oceania'),  ('NPL', 'Asia South Albers Equal Area Conic'),  ('NLD', 'Europe Albers Equal Area Conic'),  ('NCL', 'Oceania'),  ('NZL', 'Oceania'),  ('NIC', 'North America Albers Equal Area Conic'),  ('NER', 'Africa Albers Equal Area Conic'),  ('NGA', 'Africa Albers Equal Area Conic'),  ('NIU', 'Oceania'),  ('NFK', 'Oceania'),  ('MKD', 'Europe Albers Equal Area Conic'),  ('MNP', 'Oceania'),  ('NOR', 'Europe Albers Equal Area Conic'),  ('OMN', 'Asia South Albers Equal Area Conic'),  ('PAK', 'Asia South Albers Equal Area Conic'),  ('PLW', 'Oceania'),  ('PAN', 'North America Albers Equal Area Conic'),  ('PNG', 'Oceania'),  ('PRY', 'South America Albers Equal Area Conic'),  ('PER', 'South America Albers Equal Area Conic'),  ('PHL', 'Asia South Albers Equal Area Conic'),  ('PCN', 'Oceania'),  ('POL', 'Europe Albers Equal Area Conic'),  ('PRT', 'Europe Albers Equal Area Conic'),  ('PRI', 'North America Albers Equal Area Conic'),  ('QAT', 'Asia South Albers Equal Area Conic'),  ('KOR', 'Asia South Albers Equal Area Conic'),  ('MDA', 'Europe Albers Equal Area Conic'),  ('REU', 'Africa Albers Equal Area Conic'),  ('ROU', 'Europe Albers Equal Area Conic'),  ('RUS', 'Europe Albers Equal Area Conic'),  ('RWA', 'Africa Albers Equal Area Conic'),  ('BLM', 'North America Albers Equal Area Conic'),  ('SHN', 'Africa Albers Equal Area Conic'),  ('KNA', 'North America Albers Equal Area Conic'),  ('LCA', 'North America Albers Equal Area Conic'),  ('MAF', 'North America Albers Equal Area Conic'),  ('SPM', 'North America Albers Equal Area Conic'),  ('VCT', 'North America Albers Equal Area Conic'),  ('WSM', 'Oceania'),  ('SMR', 'Europe Albers Equal Area Conic'),  ('STP', 'Africa Albers Equal Area Conic'),  ('', 'Europe Albers Equal Area Conic'),  ('SAU', 'Asia South Albers Equal Area Conic'),  ('SEN', 'Africa Albers Equal Area Conic'),  ('SRB', 'Europe Albers Equal Area Conic'),  ('SYC', 'Africa Albers Equal Area Conic'),  ('SLE', 'Africa Albers Equal Area Conic'),  ('SGP', 'Asia South Albers Equal Area Conic'),  ('SXM', 'North America Albers Equal Area Conic'),  ('SVK', 'Europe Albers Equal Area Conic'),  ('SVN', 'Europe Albers Equal Area Conic'),  ('SLB', 'Oceania'),  ('SOM', 'Africa Albers Equal Area Conic'),  ('ZAF', 'Africa Albers Equal Area Conic'),  ('SGS', 'South America Albers Equal Area Conic'),  ('SSD', 'Africa Albers Equal Area Conic'),  ('ESP', 'Europe Albers Equal Area Conic'),  ('LKA', 'Asia South Albers Equal Area Conic'),  ('PSE', 'Asia South Albers Equal Area Conic'),  ('SDN', 'Africa Albers Equal Area Conic'),  ('SUR', 'South America Albers Equal Area Conic'),  ('SJM', 'Europe Albers Equal Area Conic'),  ('SWE', 'Europe Albers Equal Area Conic'),  ('CHE', 'Europe Albers Equal Area Conic'),  ('SYR', 'Asia South Albers Equal Area Conic'),  ('TJK', 'Asia South Albers Equal Area Conic'),  ('THA', 'Asia South Albers Equal Area Conic'),  ('TLS', 'Asia South Albers Equal Area Conic'),  ('TGO', 'Africa Albers Equal Area Conic'),  ('TKL', 'Oceania'),  ('TON', 'Oceania'),  ('TTO', 'North America Albers Equal Area Conic'),  ('TUN', 'Africa Albers Equal Area Conic'),  ('TUR', 'Asia South Albers Equal Area Conic'),  ('TKM', 'Asia South Albers Equal Area Conic'),  ('TCA', 'North America Albers Equal Area Conic'),  ('TUV', 'Oceania'),  ('UGA', 'Africa Albers Equal Area Conic'),  ('UKR', 'Europe Albers Equal Area Conic'),  ('ARE', 'Asia South Albers Equal Area Conic'),  ('GBR', 'Europe Albers Equal Area Conic'),  ('TZA', 'Africa Albers Equal Area Conic'),  ('UMI', 'Oceania'),  ('USA', 'North America Albers Equal Area Conic'),  ('VIR', 'North America Albers Equal Area Conic'),  ('URY', 'South America Albers Equal Area Conic'),  ('UZB', 'Asia South Albers Equal Area Conic'),  ('VUT', 'Oceania'),  ('VEN', 'South America Albers Equal Area Conic'),  ('VNM', 'Asia South Albers Equal Area Conic'),  ('WLF', 'Oceania'),  ('ESH', 'Africa Albers Equal Area Conic'),  ('YEM', 'Asia South Albers Equal Area Conic'),  ('ZMB', 'Africa Albers Equal Area Conic'),  ('ZWE', 'Africa Albers Equal Area Conic')]
dataD = json.loads(json.dumps(continentsISO))
print (wsp)
iso = 'iso3'
sr = None
for i in obj["services"]:
    if i['type'] == 'FeatureServer':
        #Get iso3 from service name
        if "pcode" in i["name"]:
            d = i["name"]
            y = d.find('/') + 1
            iso = (d[y:len(d)-6])
            for j in dataD:
                if j[0] == iso:
                    sr = j[1]
                    #print(sr)
                    sr = arcpy.SpatialReference(sr)
                    #print (obj)
                    if iso in "CIV":
                        url2 = 'https://gistmaps.itos.uga.edu/arcgis/rest/services/' + i["name"] +'/FeatureServer?f=json'
                        u = 'https://gistmaps.itos.uga.edu/arcgis/rest/services/' + i["name"] +'/FeatureServer'
                        ret = requests.get(url2)
                        obj = json.loads(json.dumps(ret.json()))
                        layersRemote = obj["layers"]
                        for l in layersRemote:
                             if l["name"] in ('Admin0', 'Admin1', 'Admin2', 'Admin3', 'Admin4', 'Admin5'):
                                map.addDataFromPath(u + "/" + str(l["id"]))
                                try:
                                    out_featureclass = os.path.join(wsp, iso + "_" + l["name"])
                                except Exception as e:
                                    print ('error: ' + str(e) )
                                layers = map.listLayers()
                                #print (out_featureclass)
                                try: 
                                    arcpy.FeatureClassToFeatureClass_conversion(layers[0], wsp, iso + l["name"])
                                except Exception as e:
                                    print ('error: ' + str(e))
                                layers = map.listLayers()
                                try:
                                    pr = arcpy.Project_management(layers[0], wsp + '\\' + iso + l["name"] + '_pr', sr)
                                except Exception as e:
                                    print('error: ' + str(e) )
                                try:
                                    arcpy.DeleteFeatures_management(out_featureclass)
                                except Exception as e:
                                    print ('error: ' + str(e))
# Out:
# C:\Users\arusso.OS\Documents\ArcGIS\Projects\MyProject39\MyProject39.gdb
# error: Failed to execute. Parameters are not valid.
# ERROR 000732: Input Features: Dataset C:\Users\arusso.OS\Documents\ArcGIS\Projects\MyProject39\MyProject39.gdb\CIV_Admin0 does not exist or is not supported
# Failed to execute (DeleteFeatures).
#
# error: Failed to execute. Parameters are not valid.
# ERROR 000732: Input Features: Dataset C:\Users\arusso.OS\Documents\ArcGIS\Projects\MyProject39\MyProject39.gdb\CIV_Admin1 does not exist or is not supported
# Failed to execute (DeleteFeatures).
#
# error: Failed to execute. Parameters are not valid.
# ERROR 000732: Input Features: Dataset C:\Users\arusso.OS\Documents\ArcGIS\Projects\MyProject39\MyProject39.gdb\CIV_Admin2 does not exist or is not supported
# Failed to execute (DeleteFeatures).
#
# error: Failed to execute. Parameters are not valid.
# ...
